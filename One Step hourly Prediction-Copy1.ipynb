# %%
from pandas import read_csv
from datetime import datetime
import matplotlib as mpl
from matplotlib import pylab as plt
import matplotlib.dates as mdates
import pandas as pd
import collections
import seaborn as sns
import numpy as np
import tensorflow as tf

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
import pickle
# Out:
# Using TensorFlow backend.

# %%
# load data
currencies = ['EXR.D.AUD.EUR.SP00.A', 'EXR.D.BRL.EUR.SP00.A', 'EXR.D.CAD.EUR.SP00.A', 'EXR.D.CNY.EUR.SP00.A', 'EXR.D.GBP.EUR.SP00.A',
              'EXR.D.HKD.EUR.SP00.A', 'EXR.D.IDR.EUR.SP00.A', 'EXR.D.INR.EUR.SP00.A', 'EXR.D.JPY.EUR.SP00.A', 'EXR.D.MYR.EUR.SP00.A']
currencies = ['EXR.D.AUD.EUR.SP00.A', 'EXR.D.BRL.EUR.SP00.A', 'EXR.D.CNY.EUR.SP00.A', 'EXR.D.GBP.EUR.SP00.A',
              'EXR.D.HKD.EUR.SP00.A', 'EXR.D.IDR.EUR.SP00.A', 'EXR.D.INR.EUR.SP00.A', 'EXR.D.JPY.EUR.SP00.A']


currencies = ['EXR.D.INR.EUR.SP00.A']

def builData(curr_key):
    
    print('Loading data and parsing date')
    
    def parse(x):
        return datetime.strptime(x, '%Y-%m-%d')

    df = read_csv('inr.csv', parse_dates=['date'], date_parser=parse)
    print('Data loaded succesfully ')

    # dataset.index.name = 'date'

    # dataset.drop('Unnamed: 0', axis=1, inplace=True)

    # mark all NA values with 0
    
    for curr in df.columns:
        if 'Unnamed' in curr:
            df.drop(curr, axis=1, inplace=True)
            print('Deleted currency: ', curr)
        
        elif curr != 'date' and curr in curr_key:
            
            print('Reading currency: ', curr)
            df[curr].fillna(0, inplace=True)
            df[curr] = df[curr].replace('-', 0)

            i = 0
            for v in df[curr]:                

                df[curr][i] = float(df[curr][i])
                if i < len(df[curr])-1 and df[curr][i] == 0:
                    df[curr][i] = float(df[curr][i+1])        
                i += 1

            print('Selected currency: ', curr)
        elif curr != 'date':
            df.drop(curr, axis=1, inplace=True)  
            print('Deleted currency: ', curr)


    df.info()
    print(df.head(5))
    curr_key = df.columns
    return df, curr_key[1:]

# %%
#df, curr_key = builData(currencies)
#df.to_pickle('currency_1')

# %%
def prepareData(df):
    #creating train and test sets
    start_date = '1999-01-04'
    start = 365 * 10 #2015
    # df.columns.drop(['Unnamed: 0', 'date'])

    dataset = df.values

    dataset = np.array(sorted(dataset, key=lambda p: p[0], reverse=False))
    dataset = dataset[-start:, 1:].astype(np.float64)
    print(dataset.shape)
    n_curr = len(df.columns) - 1

    train_size = int(dataset.shape[0]*0.8)

    train = dataset[:train_size, :]
    valid = dataset[train_size:, :]
    #converting dataset into x_train and y_train
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(train)
    scaled_data_test = scaler.fit_transform(valid)

    x_train, y_train = [], []
    x_test, y_test = [], []

    lookback = 7*4
    for i in range(lookback,len(train)):
        x_train.append(scaled_data[i-lookback:i,:])
        y_train.append(scaled_data[i,:])
    for i in range(lookback,len(valid)):
        x_test.append(scaled_data_test[i-lookback:i,:])
        y_test.append(scaled_data_test[i,:])

    x_train, y_train = np.array(x_train), np.array(y_train)
    x_test, y_test = np.array(x_test), np.array(y_test)

    x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1], n_curr))
    x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1], n_curr))
    
    #indices = np.arange(x_train.shape[0])
    #np.random.shuffle(indices)

    #x_train = x_train[indices, :, :]
    #y_train = y_train[indices, :]

    print(x_train.shape)
    print(y_train.shape)
    return x_train, y_train, x_test, y_test, scaler

# %%
def buildModel(x_train, y_train, curr_key):
    i = 0
    units = 50
    for curr in curr_key:
        # create and fit the LSTM network
        model = Sequential()
        model.add(LSTM(units=units, return_sequences=True, input_shape=(x_train.shape[1], 1)))
        model.add(LSTM(units=units))
        model.add(Dense(1))
        X = x_train[:, :, i].reshape(x_train.shape[0], x_train.shape[1], 1)
        y = y_train[:, i]

        model.compile(loss='mean_squared_error', optimizer='Adamax')
        history = model.fit(X, y, epochs=1, batch_size=1, verbose=1)
        filename = curr + '_model.sav'
        pickle.dump(model, open(filename, 'wb'))
        print('Model created :', curr)

        i += 1
        model = 0
        
    print('Total created models: ', i)

# %%
def loadModel(curr_key):
    i = 0
    models = []
    for curr in curr_key:
        # load the model from disk
        filename = curr + '_model.sav'
        loaded_model = pickle.load(open(filename, 'rb'))
        models.append(loaded_model)
        print('Loaded model: ', filename)
    return models

# %%
def predict(x_test, models):
    predict_arr = np.zeros((x_test.shape[0], len(models)))

    i = 0
    for model in models:
        X = x_test[:, :, i].reshape(x_test.shape[0], x_test.shape[1], 1)
        
        prediction = model.predict(X)
        predict_arr[:, i] = prediction.reshape(prediction.shape[0],)
        i += 1
    return predict_arr

# %%
def getMSE(x_train, y_train, models, scaler):
    i = 0
    mse_arr = []
    ps = 0*y_train
    for model in models:
        X = x_train[:, :, i].reshape(x_train.shape[0], x_train.shape[1], 1)
        p = model.predict(X)
        ps[:, i] = p.reshape(p.shape[0],)
        i += 1

    y_train_inv = scaler.inverse_transform(y_train)
    predict = scaler.inverse_transform(ps)
        
    for j in range(len(models)):
        mse = mean_squared_error(y_train_inv[:, j], predict[:, j])
        mse_arr.append(mse)
    return mse_arr

# %%
df = pd.read_pickle('currency_1')
df.head(5)
# Out:
#         date EXR.D.INR.EUR.SP00.A
# 0 2019-07-31              76.6965
# 1 2019-07-31              76.6965
# 2 2019-07-30              76.7575
# 3 2019-07-29               76.474
# 4 2019-07-26                76.74

# %%
x_train, y_train, x_test, y_test, scaler = prepareData(df)
# Out:
# (3650, 1)
# (2892, 28, 1)
# (2892, 1)

# %%
curr_key = currencies
print(curr_key)
buildModel(x_train, y_train, curr_key)
# Out:
# ['EXR.D.INR.EUR.SP00.A']
# Epoch 1/1
# 2892/2892 [==============================] - 55s 19ms/step - loss: 0.0044
# Model created : EXR.D.INR.EUR.SP00.A
# Total created models:  1

# %%
print(curr_key)
# Out:
# ['EXR.D.INR.EUR.SP00.A']

# %%
models = loadModel(curr_key)
# Out:
# Loaded model:  EXR.D.INR.EUR.SP00.A_model.sav

# %%
predict_arr = predict(x_test, models)

# %%
y_test_inv = scaler.inverse_transform(y_test)
predict = scaler.inverse_transform(predict_arr)



horizon = 100

# %%
def getActions(y, V, Cash, T):
    n = V.shape[1]
    t_cur = T
    t_prev = t_cur - 1
    t_prev2 = t_prev - 1
    t_next = t_cur + 1
    
    X_eur = Cash[t_cur, -1]
    X_new = X_eur
    A = []
    
    for c in range(n):
        action = ''
        X = 0

        d_prev = y[t_prev, c] - y[t_prev2, c]
        d_cur = y[t_cur, c] - y[t_prev, c]
        d_next = V[t_next, c] - y[t_cur, c]

        if d_prev > 0 and d_cur > 0 and d_next < 0:
            action = 'BUY'

        elif d_prev > 0 and d_cur < 0 and d_next < 0:
            action = 'BUY'

        elif d_prev < 0 and d_cur < 0 and d_next > 0:
            action = 'SELL'

        elif d_prev < 0 and d_cur > 0 and d_next > 0:
            action = 'SELL'
        A.append([action, X])
    
    return A

# %%
for j in range(len(curr_key)):
    mse = mean_squared_error(y_test[:, j], predict_arr[:, j])
    print(mse)
# Out:
# 0.0025613068810615485

# %%
V = predict[-horizon-1:, :]
y = y_test_inv[-horizon-1:, :]
V[0, :] = y_test_inv[-horizon-1, :]
n = V.shape[1]
initial_cash = 1000
X_buy = 0*V
X_sell = 0*V

Cash = np.zeros((horizon+1, n + 1))
Cash[0, -1] = initial_cash
Cash[1, -1] = initial_cash
print('n ', n)

for t in range(2, horizon-1):
    A = getActions(y, V, Cash, t)
    Cash[t, :] = Cash[t-1, :]
    b = 0
    c = 0
    
    print('Jour ', t)
    for a in A:        
        if a[0] == 'SELL' and Cash[t, c] > 0:
            print(str(a[0]) + ' ' + str(Cash[t, c]) + ' ' + str(curr_key[c]) + ' rate :' + str(y[t, c]))
            
            Cash[t, -1] = Cash[t, -1] + Cash[t, c]/y[t, c]
            Cash[t, c] = Cash[t, c] -  Cash[t, c]
            X_sell[t, c] = 1
            
            
            print('Euro after sell ', Cash[t, -1])
        if a[0] == 'BUY':
            b += 1
        c += 1
          
    c = 0    
    for a in A:
            
        if a[0] == 'BUY' and Cash[t, -1] > 0:
            
            print(str(a[0]) + ' ' + str(Cash[t, -1]*y[t, c]/b) + ' ' + str(curr_key[c]) + ' rate: ' + str(y[t, c]/b))
            
            Cash[t, c] = Cash[t, c] + Cash[t, -1]*y[t, c]/b
            Cash[t, -1] = Cash[t, -1] - Cash[t, -1]/b
            
            print('Euro after buy ', Cash[t, -1])
            X_buy[t, c] = 1
        
        c += 1
    
    print('Actions end of day: ', A)
    print('Accounts status: ', Cash[t, :])
    last_day = t

final_cash = Cash[last_day, -1]
print(final_cash)
for i in range(n):
    if y[last_day, i] != 0:
        final_cash += Cash[last_day, i]/y[last_day, i]
        initial_cash += Cash[1, i]/y[1, i]

d_growth = (final_cash/initial_cash)**(1/(last_day - 2)) - 1
                 
print('Initial cash value (eur): ', initial_cash)
print('Final cash value (eur): ', final_cash)
print('Daily growth: ', d_growth, '%')
print('Win: ', final_cash - initial_cash)
# Out:
# n  1
# Jour  2
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0. 1000.]
# Jour  3
# Actions end of day:  [['', 0]]
# Accounts status:  [   0. 1000.]
# Jour  4
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0. 1000.]
# Jour  5
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0. 1000.]
# Jour  6
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0. 1000.]
# Jour  7
# Actions end of day:  [['', 0]]
# Accounts status:  [   0. 1000.]
# Jour  8
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0. 1000.]
# Jour  9
# Actions end of day:  [['', 0]]
# Accounts status:  [   0. 1000.]
# Jour  10
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0. 1000.]
# Jour  11
# Actions end of day:  [['', 0]]
# Accounts status:  [   0. 1000.]
# Jour  12
# Actions end of day:  [['', 0]]
# Accounts status:  [   0. 1000.]
# Jour  13
# Actions end of day:  [['', 0]]
# Accounts status:  [   0. 1000.]
# Jour  14
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0. 1000.]
# Jour  15
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0. 1000.]
# Jour  16
# Actions end of day:  [['', 0]]
# Accounts status:  [   0. 1000.]
# Jour  17
# BUY 78321.50000000001 EXR.D.INR.EUR.SP00.A rate: 78.32150000000001
# Euro after buy  0.0
# Actions end of day:  [['BUY', 0]]
# Accounts status:  [78321.5     0. ]
# Jour  18
# Actions end of day:  [['BUY', 0]]
# Accounts status:  [78321.5     0. ]
# Jour  19
# SELL 78321.50000000001 EXR.D.INR.EUR.SP00.A rate :77.9945
# Euro after sell  1004.1926033245935
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1004.19260332]
# Jour  20
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1004.19260332]
# Jour  21
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.         1004.19260332]
# Jour  22
# BUY 78869.78916141523 EXR.D.INR.EUR.SP00.A rate: 78.5405
# Euro after buy  0.0
# Actions end of day:  [['BUY', 0]]
# Accounts status:  [78869.78916142     0.        ]
# Jour  23
# Actions end of day:  [['BUY', 0]]
# Accounts status:  [78869.78916142     0.        ]
# Jour  24
# Actions end of day:  [['BUY', 0]]
# Accounts status:  [78869.78916142     0.        ]
# Jour  25
# SELL 78869.78916141523 EXR.D.INR.EUR.SP00.A rate :78.06799999999998
# Euro after sell  1010.2703945459759
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1010.27039455]
# Jour  26
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1010.27039455]
# Jour  27
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.         1010.27039455]
# Jour  28
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1010.27039455]
# Jour  29
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1010.27039455]
# Jour  30
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1010.27039455]
# Jour  31
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1010.27039455]
# Jour  32
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.         1010.27039455]
# Jour  33
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.         1010.27039455]
# Jour  34
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1010.27039455]
# Jour  35
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1010.27039455]
# Jour  36
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.         1010.27039455]
# Jour  37
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1010.27039455]
# Jour  38
# BUY 79148.11865511267 EXR.D.INR.EUR.SP00.A rate: 78.3435
# Euro after buy  0.0
# Actions end of day:  [['BUY', 0]]
# Accounts status:  [79148.11865511     0.        ]
# Jour  39
# Actions end of day:  [['BUY', 0]]
# Accounts status:  [79148.11865511     0.        ]
# Jour  40
# Actions end of day:  [['BUY', 0]]
# Accounts status:  [79148.11865511     0.        ]
# Jour  41
# Actions end of day:  [['BUY', 0]]
# Accounts status:  [79148.11865511     0.        ]
# Jour  42
# Actions end of day:  [['', 0]]
# Accounts status:  [79148.11865511     0.        ]
# Jour  43
# SELL 79148.11865511267 EXR.D.INR.EUR.SP00.A rate :78.469
# Euro after sell  1008.6546108031539
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.        1008.6546108]
# Jour  44
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.        1008.6546108]
# Jour  45
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.        1008.6546108]
# Jour  46
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.        1008.6546108]
# Jour  47
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.        1008.6546108]
# Jour  48
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.        1008.6546108]
# Jour  49
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.        1008.6546108]
# Jour  50
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.        1008.6546108]
# Jour  51
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.        1008.6546108]
# Jour  52
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.        1008.6546108]
# Jour  53
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.        1008.6546108]
# Jour  54
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.        1008.6546108]
# Jour  55
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.        1008.6546108]
# Jour  56
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.        1008.6546108]
# Jour  57
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.        1008.6546108]
# Jour  58
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.        1008.6546108]
# Jour  59
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.        1008.6546108]
# Jour  60
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.        1008.6546108]
# Jour  61
# BUY 79325.13753930863 EXR.D.INR.EUR.SP00.A rate: 78.6445
# Euro after buy  0.0
# Actions end of day:  [['BUY', 0]]
# Accounts status:  [79325.13753931     0.        ]
# Jour  62
# Actions end of day:  [['BUY', 0]]
# Accounts status:  [79325.13753931     0.        ]
# Jour  63
# Actions end of day:  [['', 0]]
# Accounts status:  [79325.13753931     0.        ]
# Jour  64
# Actions end of day:  [['', 0]]
# Accounts status:  [79325.13753931     0.        ]
# Jour  65
# Actions end of day:  [['', 0]]
# Accounts status:  [79325.13753931     0.        ]
# Jour  66
# Actions end of day:  [['BUY', 0]]
# Accounts status:  [79325.13753931     0.        ]
# Jour  67
# SELL 79325.13753930863 EXR.D.INR.EUR.SP00.A rate :78.0005
# Euro after sell  1016.9824236935485
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1016.98242369]
# Jour  68
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1016.98242369]
# Jour  69
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.         1016.98242369]
# Jour  70
# BUY 80034.99127104672 EXR.D.INR.EUR.SP00.A rate: 78.6985
# Euro after buy  0.0
# Actions end of day:  [['BUY', 0]]
# Accounts status:  [80034.99127105     0.        ]
# Jour  71
# Actions end of day:  [['BUY', 0]]
# Accounts status:  [80034.99127105     0.        ]
# Jour  72
# Actions end of day:  [['BUY', 0]]
# Accounts status:  [80034.99127105     0.        ]
# Jour  73
# SELL 80034.99127104672 EXR.D.INR.EUR.SP00.A rate :78.5705
# Euro after sell  1018.6392000947776
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  74
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  75
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  76
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  77
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  78
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  79
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  80
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  81
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  82
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  83
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  84
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  85
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  86
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  87
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  88
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  89
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  90
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  91
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  92
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  93
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  94
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  95
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  96
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  97
# Actions end of day:  [['', 0]]
# Accounts status:  [   0.         1018.63920009]
# Jour  98
# Actions end of day:  [['SELL', 0]]
# Accounts status:  [   0.         1018.63920009]
# 1018.6392000947776
# Initial cash value (eur):  1000.0
# Final cash value (eur):  1018.6392000947776
# Daily growth:  0.0001923895358986183 %
# Win:  18.639200094777607

# %%
mse_arr = getMSE(x_train, y_train, models, scaler)
for i in range(len(curr_key)):
    xs = np.arange(int(horizon))
    fig = plt.figure(figsize=(12, 6))
    ax = fig.add_subplot(1, 1, 1)

    ax.plot(xs, y_test_inv[-horizon:, i], label='Real ' + curr_key[i], lw=2, color='black')
    ax.plot(xs, predict[-horizon:, i], label='Forecast ' + curr_key[i], lw=2, color='blue')
    

    rmse = mse_arr[i]

    rmse_max = [float(p) + float(rmse)/2 for p in predict[:, i]]
    rmse_min = [float(p) - float(rmse)/2 for p in predict[:, i]]

    ax.fill_between(xs, rmse_max[-horizon:], rmse_min[-horizon:], color='red', alpha=0.2)
    plt.show()
